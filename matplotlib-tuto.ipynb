# %% [markdown]
# Load Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Basic Graph

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

# Resize Graph (dpi specifies pixels per inch. When saving probably should use 300 if possible)
plt.figure(figsize=(4,3), dpi=150)

##Line 1

# Keyword Argument Notation
# plt.plot(x,y, label='2x', color='red', linewidth=2, marker='.', linestyle='--', markersize=10, markeredgecolor='green')

# Shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x',)

## Line 2

# Select interval we want to plot points at
x2 = np.arange(0,4.5,0.5)

# Plot part of the graph as line
plt.plot(x2[:6], x2[:6]**2, 'r', label='x^2')

# Plot part of the graph as dot
plt.plot(x2[4:], x2[4:]**2, 'r--')

# Add title (specify font parameters with fontdict)
plt.title('Our First Graph', fontdict={'fontname':'Comic Sans MS','fontsize':20})

# X and y labels
plt.xlabel('X Axis', fontdict={'fontname':'Arial'})
plt.ylabel('Y Axis', fontdict={'fontname':'Arial'})

# X, Y axis Tickmarks (scale of the graph)
plt.xticks([0,1,2,3])
plt.yticks([0,2,4,6,8,10])

# Add legend
plt.legend()

# Save figure (dpi 300 is good when saving so graph has high resolutions)
plt.savefig('firstgraph.png', dpi=300)

#s  Show plot
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

plt.figure(figsize=(6,4), dpi=100)

bars = plt.bar(labels, values)

# bars[0].set_hatch('/')
# bars[1].set_hatch('O')
# bars[2].set_hatch('*')

# Shorthand
patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %% [markdown]
# ## Real World Examples

# %% [markdown]
# ### Line Graph

# %%
gas = pd.read_csv('gas_prices.csv')

plt.figure(figsize=(8,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-')
plt.plot(gas.Year, gas['South Korea'], 'g.-')
plt.plot(gas.Year, gas.Australia, 'y.-')

# Another Way to plot many values!
# countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
# for country in gas:
#     if country in countries_to_look_at:
#         plt.plot(gas.Year, gas[country], marker='.')

plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Asus\Documents\Python\Pandas\matplotlib-tuto.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/Python/Pandas/matplotlib-tuto.ipynb#ch0000009?line=0'>1</a> gas = pd.read_csv('gas_prices.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/Python/Pandas/matplotlib-tuto.ipynb#ch0000009?line=2'>3</a> plt.figure(figsize=(8,5))
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Documents/Python/Pandas/matplotlib-tuto.ipynb#ch0000009?line=4'>5</a> plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18})
#
# NameError: name 'pd' is not defined
